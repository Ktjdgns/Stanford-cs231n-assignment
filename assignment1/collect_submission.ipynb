# %%
# from google.colab import drive

# drive.mount('/content/drive')

# TODO: Enter the path in your Drive of the assignment.
# e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = '/home/kim1484/cs231n/assignments/assignment1/'

assert FOLDERNAME is not None, "[!] Enter the foldername."

# %% [markdown]
# # Collect Submission - Zip + Generate PDF
#
# Run this notebook once you have completed all the other notebooks: `knn.ipynb`, `softmax.ipynb`, `two_layer_net.ipynb`, `features.ipynb`, and `FullyConnectedNets.ipynb`.
#
# It will:
#
# * Generate a zip file of your code (`.py` and `.ipynb`) called `a1_code_submission.zip`.
# * Convert all notebooks into a single PDF file called `a1_inline_submission.pdf`.
#
# If your submission for this step was successful, you should see the following display message:
#
# `### Done! Please submit a1_code_submission.zip and a1_inline_submission.pdf to Gradescope. ###`
#
# Make sure to download the zip and pdf file locally to your computer, then submit to Gradescope. Congrats on succesfully completing the assignment!

# %%
# %cd drive/My\ Drive
# %cd $FOLDERNAME
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-plain-generic texlive-latex-extra pandoc --fix-missing
# !pip install PyPDF2
# !bash collectSubmission.sh

import os
os.chdir("/home/kim1484/cs231n/assignments/assignment1") 
# !pip install -q nbconvert jupyter PyPDF2 
# !pip install -q pyppeteer
# !python - <<'PY'
# import pyppeteer, asyncio
# asyncio.get_event_loop().run_until_complete(pyppeteer.chromium_downloader.download_chromium())
# PY

# !bash collectSubmission.sh
# Out:
# ### Zipping source ###
# ### Exporting notebooks to PDF (webpdf) ###
#  - knn.ipynb -> pdf_build/knn.pdf
# [NbConvertApp] Converting notebook knn.ipynb to webpdf
# [NbConvertApp] WARNING | Alternative text is missing on 3 image(s).
# [NbConvertApp] Building PDF
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 602625 bytes to knn.pdf
#  - softmax.ipynb -> pdf_build/softmax.pdf
# [NbConvertApp] Converting notebook softmax.ipynb to webpdf
# [NbConvertApp] WARNING | Alternative text is missing on 5 image(s).
# [NbConvertApp] Building PDF
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 627522 bytes to softmax.pdf
#  - two_layer_net.ipynb -> pdf_build/two_layer_net.pdf
# [NbConvertApp] Converting notebook two_layer_net.ipynb to webpdf
# [NbConvertApp] WARNING | Alternative text is missing on 2 image(s).
# [NbConvertApp] Building PDF
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 458148 bytes to two_layer_net.pdf
#  - features.ipynb -> pdf_build/features.pdf
# [NbConvertApp] Converting notebook features.ipynb to webpdf
# [NbConvertApp] WARNING | Alternative text is missing on 1 image(s).
# [NbConvertApp] Building PDF
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 496967 bytes to features.pdf
#  - FullyConnectedNets.ipynb -> pdf_build/FullyConnectedNets.pdf
# [NbConvertApp] Converting notebook FullyConnectedNets.ipynb to webpdf
# [NbConvertApp] WARNING | Alternative text is missing on 4 image(s).
# [NbConvertApp] Building PDF
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 541560 bytes to FullyConnectedNets.pdf
# ### Merging PDFs ###
# [done] Merged -> a1_inline_submission.pdf
# ### Done! Submit a1_code_submission.zip and a1_inline_submission.pdf ###
